# %% [markdown]
# # CAPITAL FINITO

# %%
# %run ruleta.py -c 10000 -n 10 -s m -a f
# Out:
# Graficando flujo de caja...
# Graficando histograma...
# Graficando flujo de caja...
# Graficando histograma...

# %%
# %run ruleta.py -c 10000 -n 10 -s o -a f
# Out:
# Graficando flujo de caja...
# Graficando histograma...
# /home/gonzalo/anaconda3/lib/python3.12/site-packages/IPython/core/pylabtools.py:170: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)
# Graficando flujo de caja...
# Graficando histograma...

# %%
# %run ruleta.py -c 10000 -n 10 -s d -a f
# Out:
# Graficando flujo de caja...
# Graficando histograma...
# Graficando flujo de caja...
# Graficando histograma...

# %%
# %run ruleta.py -c 10000 -n 10 -s f -a f
# Out:
# Graficando flujo de caja...
# Graficando histograma...
# /home/gonzalo/anaconda3/lib/python3.12/site-packages/IPython/core/pylabtools.py:170: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)
# Graficando flujo de caja...
# Graficando histograma...

# %% [markdown]
# # CAPITAL INFINITO

# %%
# %run ruleta.py -c 10000 -n 10 -s m -a i
# Out:
# Graficando flujo de caja...
# Graficando histograma...
# /home/gonzalo/anaconda3/lib/python3.12/site-packages/IPython/core/pylabtools.py:170: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)
# Graficando flujo de caja...
# Graficando histograma...
# /home/gonzalo/anaconda3/lib/python3.12/site-packages/IPython/core/pylabtools.py:170: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# %run ruleta.py -c 10000 -n 10 -s d -a i
# Out:
# Graficando flujo de caja...
# Graficando histograma...
# /home/gonzalo/anaconda3/lib/python3.12/site-packages/IPython/core/pylabtools.py:170: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)
# Graficando flujo de caja...
# Graficando histograma...

# %%
# %run ruleta.py -c 10000 -n 10 -s f -a i
# Out:
# Graficando flujo de caja...
# Graficando histograma...
# /home/gonzalo/anaconda3/lib/python3.12/site-packages/IPython/core/pylabtools.py:170: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)
# Graficando flujo de caja...
# Graficando histograma...

# %%
# %run ruleta.py -c 10000 -n 10 -s o -a i
# Out:
# Graficando flujo de caja...
# Graficando histograma...
# /home/gonzalo/anaconda3/lib/python3.12/site-packages/IPython/core/pylabtools.py:170: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)
# Graficando flujo de caja...
# Graficando histograma...
# [       flujo_caja  apuestas   wins  frec_rel
# 1           10000         5  False  0.000000
# 2            9995         5  False  0.000000
# 3            9990         5  False  0.000000
# 4            9985         5  False  0.000000
# 5            9980         5  False  0.000000
# ...           ...       ...    ...       ...
# 9996         7280         5  False  0.486194
# 9997         7275         5   True  0.486246
# 9998         7280        10  False  0.486197
# 9999         7270         5   True  0.486249
# 10000        7275        10   True  0.486300
#
# [10000 rows x 4 columns],        flujo_caja  apuestas   wins  frec_rel
# ...
